# %%
# !python data/generate.py --topology nsf --distribution uniform --difficulty easy --requests 300 --num-files 5
# Out:
# Generated: data\nsf_uniform_easy_s1.json
#   Nodes: 14, Links: 22, Requests: 300
#   Server nodes: 4
# Generated: data\nsf_uniform_easy_s2.json
#   Nodes: 14, Links: 22, Requests: 300
#   Server nodes: 4
# Generated: data\nsf_uniform_easy_s3.json
#   Nodes: 14, Links: 22, Requests: 300
#   Server nodes: 4
# Generated: data\nsf_uniform_easy_s4.json
#   Nodes: 14, Links: 22, Requests: 300
#   Server nodes: 4
# Generated: data\nsf_uniform_easy_s5.json
#   Nodes: 14, Links: 22, Requests: 300
#   Server nodes: 4
